# %% [markdown]
# ### Реализация задачи определения тональности текста на датасете англоязычных твитов (toxic_comments.csv) при помощи deeppavlov
# #### Устанавливаем библиотеку deeppavlov

# %%
# !pip install deeppavlov
# Out:
# Requirement already satisfied: deeppavlov in f:\anaconda3\envs\ml3\lib\site-packages (1.7.0)
# Requirement already satisfied: fastapi<=0.89.1,>=0.47.0 in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (0.89.1)
# Requirement already satisfied: filelock<3.10.0,>=3.0.0 in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (3.9.1)
# Requirement already satisfied: nltk<3.10.0,>=3.2.4 in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (3.9.1)
# Requirement already satisfied: numpy<1.24 in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (1.23.5)
# Requirement already satisfied: pandas<1.6.0,>=1.0.0 in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (1.5.3)
# Requirement already satisfied: prometheus-client<=1.16.0,>=0.13.0 in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (0.21.0)
# Requirement already satisfied: pydantic<2 in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (1.10.20)
# Requirement already satisfied: pybind11==2.10.3 in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (2.10.3)
# Requirement already satisfied: requests<3.0.0,>=2.19.0 in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (2.32.3)
# Requirement already satisfied: tqdm<4.65.0,>=4.42.0 in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (4.64.1)
# Requirement already satisfied: uvicorn<0.19.0,>=0.13.0 in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (0.18.3)
# Requirement already satisfied: wheel in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (0.44.0)
# Requirement already satisfied: scikit-learn<1.1.0,>=0.24 in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (1.0.2)
# Requirement already satisfied: scipy==1.10.0 in f:\anaconda3\envs\ml3\lib\site-packages (from deeppavlov) (1.10.0)
# Requirement already satisfied: starlette==0.22.0 in f:\anaconda3\envs\ml3\lib\site-packages (from fastapi<=0.89.1,>=0.47.0->deeppavlov) (0.22.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in f:\anaconda3\envs\ml3\lib\site-packages (from starlette==0.22.0->fastapi<=0.89.1,>=0.47.0->deeppavlov) (4.6.2)
# Requirement already satisfied: click in f:\anaconda3\envs\ml3\lib\site-packages (from nltk<3.10.0,>=3.2.4->deeppavlov) (8.1.8)
# Requirement already satisfied: joblib in f:\anaconda3\envs\ml3\lib\site-packages (from nltk<3.10.0,>=3.2.4->deeppavlov) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in f:\anaconda3\envs\ml3\lib\site-packages (from nltk<3.10.0,>=3.2.4->deeppavlov) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in f:\anaconda3\envs\ml3\lib\site-packages (from pandas<1.6.0,>=1.0.0->deeppavlov) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in f:\anaconda3\envs\ml3\lib\site-packages (from pandas<1.6.0,>=1.0.0->deeppavlov) (2024.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in f:\anaconda3\envs\ml3\lib\site-packages (from pydantic<2->deeppavlov) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\anaconda3\envs\ml3\lib\site-packages (from requests<3.0.0,>=2.19.0->deeppavlov) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\anaconda3\envs\ml3\lib\site-packages (from requests<3.0.0,>=2.19.0->deeppavlov) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\anaconda3\envs\ml3\lib\site-packages (from requests<3.0.0,>=2.19.0->deeppavlov) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda3\envs\ml3\lib\site-packages (from requests<3.0.0,>=2.19.0->deeppavlov) (2024.12.14)
# Requirement already satisfied: threadpoolctl>=2.0.0 in f:\anaconda3\envs\ml3\lib\site-packages (from scikit-learn<1.1.0,>=0.24->deeppavlov) (3.5.0)
# Requirement already satisfied: colorama in f:\anaconda3\envs\ml3\lib\site-packages (from tqdm<4.65.0,>=4.42.0->deeppavlov) (0.4.6)
# Requirement already satisfied: h11>=0.8 in f:\anaconda3\envs\ml3\lib\site-packages (from uvicorn<0.19.0,>=0.13.0->deeppavlov) (0.14.0)
# Requirement already satisfied: six>=1.5 in f:\anaconda3\envs\ml3\lib\site-packages (from python-dateutil>=2.8.1->pandas<1.6.0,>=1.0.0->deeppavlov) (1.16.0)
# Requirement already satisfied: sniffio>=1.1 in f:\anaconda3\envs\ml3\lib\site-packages (from anyio<5,>=3.4.0->starlette==0.22.0->fastapi<=0.89.1,>=0.47.0->deeppavlov) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in f:\anaconda3\envs\ml3\lib\site-packages (from anyio<5,>=3.4.0->starlette==0.22.0->fastapi<=0.89.1,>=0.47.0->deeppavlov) (1.2.0)

# %%
from deeppavlov import build_model # Импортируем функцию build_model из DeepPavlov
import pandas as pd
df = pd.read_csv('datasets/toxic_comments.csv', encoding="utf-8", on_bad_lines="skip", engine='python')

# %% [markdown]
# ### Усложнение 1: использовать предобработку (лемматизацию, векторизацию)

# %%
# !pip install pymorphy2
from sklearn.feature_extraction.text import TfidfVectorizer
import pymorphy2
import re

# Инициализация лемматизатора
morph = pymorphy2.MorphAnalyzer()

# Функция для предобработки текста
def preprocess_text(text):
    # Удаляем спецсимволы и цифры
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    # Приводим текст к нижнему регистру
    text = text.lower()
    # Лемматизируем
    words = text.split()
    return ' '.join(morph.parse(word)[0].normal_form for word in words)

def vectorizer_text(text_series):
    # Векторизация текста с помощью TfidfVectorizer
    tfidf_vectorizer = TfidfVectorizer(max_features=5000)  # Ограничиваем до 5000 наиболее важных признаков
    tfidf_matrix = tfidf_vectorizer.fit_transform(text_series)  # Преобразуем текст в векторный формат
    return tfidf_matrix

# Выполним предобработку к тексту
df['clean_text'] = df['text'].apply(preprocess_text)

# Выполним векторизацию к тексту
df['vectorized_text'] = list(vectorizer_text(df['clean_text']))
# Out:
# Requirement already satisfied: pymorphy2 in f:\anaconda3\envs\ml3\lib\site-packages (0.9.1)
# Requirement already satisfied: dawg-python>=0.7.1 in f:\anaconda3\envs\ml3\lib\site-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in f:\anaconda3\envs\ml3\lib\site-packages (from pymorphy2) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in f:\anaconda3\envs\ml3\lib\site-packages (from pymorphy2) (0.6.2)

# %%
# Определяем список фраз для анализа
phrases = df['clean_text'].tolist()
# Создаем модель на основе предобученного BERT, настроенного для классификации оскорблений на английском языке
model = build_model('insults_kaggle_bert', download=True, install=True)
# Прогоняем фразы через модель, чтобы получить метки (оскорбление(Insult) или нет(Not Insult))
labels = model(phrases)
df['tone'] = labels
display(df.head(50))
# Out:
# F:\anaconda3\envs\ML3\lib\site-packages\huggingface_hub\file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2025-01-12 21:17:22.577 WARNING in 'deeppavlov.core.models.torch_model'['torch_model'] at line 96: Unable to place component TorchTransformersClassifierModel on GPU, since no CUDA GPUs are available. Using CPU.
#     Unnamed: 0                                               text  toxic  \
# 0            0  Explanation\nWhy the edits made under my usern...      0
# 1            1  D'aww! He matches this background colour I'm s...      0
# 2            2  Hey man, I'm really not trying to edit war. It...      0
# 3            3  "\nMore\nI can't make any real suggestions on ...      0
# 4            4  You, sir, are my hero. Any chance you remember...      0
# 5            5  "\n\nCongratulations from me as well, use the ...      0
# 6            6       COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK      1
# 7            7  Your vandalism to the Matt Shirvington article...      0
# 8            8  Sorry if the word 'nonsense' was offensive to ...      0
# 9            9  alignment on this subject and which are contra...      0
# 10          10  "\nFair use rationale for Image:Wonju.jpg\n\nT...      0
# 11          11  bbq \n\nbe a man and lets discuss it-maybe ove...      0
# 12          12  Hey... what is it..\n@ | talk .\nWhat is it......      1
# 13          13  Before you start throwing accusations and warn...      0
# 14          14  Oh, and the girl above started her arguments w...      0
# 15          15  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...      0
# 16          16  Bye! \n\nDon't look, come or think of comming ...      1
# 17          17   REDIRECT Talk:Voydan Pop Georgiev- Chernodrinski      0
# 18          18  The Mitsurugi point made no sense - why not ar...      0
# 19          19  Don't mean to bother you \n\nI see that you're...      0
# 20          20  "\n\n Regarding your recent edits \n\nOnce aga...      0
# 21          21  "\nGood to know. About me, yeah, I'm studying ...      0
# 22          22  "\n\n Snowflakes are NOT always symmetrical! \...      0
# 23          23  "\n\n The Signpost: 24 September 2012 \n\n Rea...      0
# 24          24  "\n\nRe-considering 1st paragraph edit?\nI don...      0
# 25          25  Radial symmetry \n\nSeveral now extinct lineag...      0
# 26          26  There's no need to apologize. A Wikipedia arti...      0
# 27          27  Yes, because the mother of the child in the ca...      0
# 28          28  "\nOk. But it will take a bit of work but I ca...      0
# 29          29  "== A barnstar for you! ==\n\n  The Real Life ...      0
# 30          30  How could I post before the block expires?  Th...      0
# 31          31  Not sure about a heading of 'Fight for Freedom...      0
# 32          32  Praise \n\nlooked at this article about 6 mont...      0
# 33          33  I was able to post the above list so quickly b...      0
# 34          34  "\nWell, not ""before the process"" but ""befo...      0
# 35          35  "\n\nNot at all, you are making a straw man ar...      0
# 36          36  "\n\n ""Mainland Asia"" includes ""the lower b...      0
# 37          37  pretty much everyone from warren county/surrou...      0
# 38          38  Hi Explicit, can you block O Fenian for edit-w...      0
# 39          39  Notability of Rurika Kasuga\nA tag has been pl...      0
# 40          40  "\n Sure, but the lead must briefly summarize ...      0
# 41          41  TFD \n\nI think we just eced. I think we respo...      0
# 42          42  You are gay or antisemmitian? \n\nArchangel WH...      1
# 43          43           FUCK YOUR FILTHY MOTHER IN THE ASS, DRY!      1
# 44          44  I'm Sorry \n\nI'm sorry I screwed around with ...      1
# 45          45  I don't believe the Lisak criticism present th...      0
# 46          46  You had a point, and it's now ammended with ap...      0
# 47          47  In other words, you're too lazy to actually po...      0
# 48          48  "\nAs for your claims of ""stalking"", that is...      0
# 49          49  "::::Jmabel; in regards to predominant scholar...      0
#
#                                            clean_text  \
# 0   explanation why the edits made under my userna...
# 1   daww he matches this background colour im seem...
# 2   hey man im really not trying to edit war its j...
# 3   more i cant make any real suggestions on impro...
# 4   you sir are my hero any chance you remember wh...
# 5   congratulations from me as well use the tools ...
# 6        cocksucker before you piss around on my work
# 7   your vandalism to the matt shirvington article...
# 8   sorry if the word nonsense was offensive to yo...
# 9   alignment on this subject and which are contra...
# 10  fair use rationale for imagewonjujpg thanks fo...
# 11  bbq be a man and lets discuss itmaybe over the...
# 12  hey what is it talk what is it an exclusive gr...
# 13  before you start throwing accusations and warn...
# 14  oh and the girl above started her arguments wi...
# 15  juelz santanas age in juelz santana was years ...
# 16  bye dont look come or think of comming back to...
# 17     redirect talkvoydan pop georgiev chernodrinski
# 18  the mitsurugi point made no sense why not argu...
# 19  dont mean to bother you i see that youre writi...
# 20  regarding your recent edits once again please ...
# 21    good to know about me yeah im studying nowdeepu
# 22  snowflakes are not always symmetrical under ge...
# 23  the signpost september read this signpost in f...
# 24  reconsidering st paragraph edit i dont underst...
# 25  radial symmetry several now extinct lineages i...
# 26  theres no need to apologize a wikipedia articl...
# 27  yes because the mother of the child in the cas...
# 28  ok but it will take a bit of work but i cant q...
# 29  a barnstar for you the real life barnstar lets...
# 30  how could i post before the block expires the ...
# 31  not sure about a heading of fight for freedom ...
# 32  praise looked at this article about months ago...
# 33  i was able to post the above list so quickly b...
# 34  well not before the process but before how we ...
# 35  not at all you are making a straw man argument...
# 36  mainland asia includes the lower basin of chin...
# 37  pretty much everyone from warren countysurroun...
# 38  hi explicit can you block o fenian for editwar...
# 39  notability of rurika kasuga a tag has been pla...
# 40  sure but the lead must briefly summarize armen...
# 41  tfd i think we just eced i think we responded ...
# 42  you are gay or antisemmitian archangel white t...
# 43             fuck your filthy mother in the ass dry
# 44  im sorry im sorry i screwed around with someon...
# 45  i dont believe the lisak criticism present the...
# 46  you had a point and its now ammended with appr...
# 47  in other words youre too lazy to actually poin...
# 48  as for your claims of stalking that is absolut...
# 49  jmabel in regards to predominant scholary cons...
#
#                                       vectorized_text        tone
# 0     (0, 1173)\t0.1381053351696153\n  (0, 1420)\t...  Not Insult
# 1     (0, 1806)\t0.24961010930058378\n  (0, 921)\t...  Not Insult
# 2     (0, 874)\t0.2010046334121889\n  (0, 29)\t0.2...  Not Insult
# 3     (0, 1866)\t0.11917766467274624\n  (0, 545)\t...  Not Insult
# 4     (0, 1702)\t0.2846932570208014\n  (0, 1851)\t...  Not Insult
# 5     (0, 1745)\t0.43162263669804446\n  (0, 1801)\...  Not Insult
# 6     (0, 1883)\t0.43868616429245694\n  (0, 130)\t...      Insult
# 7     (0, 187)\t0.3447985796031575\n  (0, 1871)\t0...      Insult
# 45    (0, 1725)\t0.07765602900592959\n  (0, 1836)\...  Not Insult
# 46    (0, 1166)\t0.40478331404368517\n  (0, 110)\t...  Not Insult
# 47    (0, 739)\t0.2906012868355122\n  (0, 290)\t0....  Not Insult
# 48    (0, 295)\t0.11063917197287602\n  (0, 1781)\t...  Not Insult
# 49    (0, 1118)\t0.07037817628901252\n  (0, 1265)\...  Not Insult

# %% [markdown]
# ### Усложнение 2: решить ту же задачу для русского языка

# %%
df = pd.read_csv('datasets/rusentitweet_full.csv', encoding="utf-8", on_bad_lines="skip", engine='python')
# Создаем модель на основе предобученного BERT, настроенного для анализа тональности на русском языке
model = build_model('rusentiment_convers_bert', download=True, install=True)
# Выполним предобработку к тексту
df['clean_text'] = df['text'].apply(preprocess_text)

# Выполним векторизацию к тексту
df['vectorized_text'] = list(vectorizer_text(df['clean_text']))

phrases = df['clean_text'].tolist()
labels = model(phrases)
df['tone'] = labels #записываем данные в tone
display(df.head(50))
# Out:
# F:\anaconda3\envs\ML3\lib\site-packages\huggingface_hub\file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased-conversational were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased-conversational and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2025-01-12 21:17:32.63 WARNING in 'deeppavlov.core.models.torch_model'['torch_model'] at line 96: Unable to place component TorchTransformersClassifierModel on GPU, since no CUDA GPUs are available. Using CPU.
#     Unnamed: 0                                               text     label  \
# 0            0                               @varlamov @McFaul На      skip
# 1            1  велл они  всё равно что мусор так что ничего с...  negative
# 2            2  "трезвая жизнь какая-то такая стрёмная"\n(с) а...  negative
# 3            3  Ой какие неожиданные результаты 🤭 https://t.co...   neutral
# 4            4  @Shvonder_chief @dimsmirnov175 На заборе тоже ...   neutral
# 5            5      @idkwhht мы тоже мебельная компания уджина😳😳😳   neutral
# 6            6  Счастья здоровья 10 классникам https://t.co/M9...    speech
# 7            7                                 @dntbliev НЕ ПАЛИ.   neutral
# 8            8                   @BTS_twt ты такой красивый 😭😭😭🥺💓  positive
# 9            9                      @Ladyzchensk Цыган , хуле ...  negative
# 10          10  @nikogdanahui1 С днём рождения 🥳 \nУспехов и п...    speech
# 11          11  @okdaa @wifeyoonminn @Y_Yoon_ Но ты очень крас...  positive
# 12          12  @Luvyurbodybby "Я играю в волейбол не ради смы...   neutral
# 13          13                            @Susanoo51489064 ВХВХВХ  positive
# 14          14  @tutby 📊\n-- «День Выборов Президента Беларуси...   neutral
# 15          15                       @ZippinkC @lenny_lanzz ПЛАЧУ  negative
# 16          16  @BettyBoo_rus Надо тоже надоедать начать) Спас...   neutral
# 17          17  @shn_shah Кеча топилмагунча уйқим кемаганди😅\n...      skip
# 18          18                @yoursungshine малышка спи сладко ❤  positive
# 19          19  @lIl__muna__ @kpop_asiangirl хех, я просто объ...   neutral
# 20          20  @bLianaaaa Я також творю хуйню, тому давай тво...  negative
# 21          21  @gygwas Я уже готова быть выебанной через экра...  negative
# 22          22  @viktoshamurrr7 @CMEPTU___HET @derella9 Кладби...      skip
# 23          23     как же я люблю титьки  https://t.co/C2M8rMDFyc  positive
# 24          24                        @nimitide_ne Абаммед Мухдул   neutral
# 25          25  обсуждаем последние новости. https://t.co/Bjxl...   neutral
# 26          26                    @ughdaechwitta все мужики такие  negative
# 27          27  Реакция болельщиков «Челси» на трансфер Виктор...   neutral
# 28          28                           это как то странно чтлио      skip
# 29          29  ощущаю на себе выражение «влачить своё существ...  negative
# 30          30  Вы помните, когда зарегистрировались в Твиттер...   neutral
# 31          31  стэнить гат7 было моим самым лучшим решением н...  positive
# 32          32                 @simpforkeijii АХАХА ЛАДНО СПАСИБО    speech
# 33          33  @naiveximp Вийди отсюда, розбійник писала моя ...   neutral
# 34          34               @xiaogoldjoy @littlebear_j согласна.   neutral
# 35          35    @Krimoza_k @ATEEZofficial И целых два сразу🤭💖💖💖  positive
# 36          36       @Pooh72Rus а весь список огласить не судьба?  negative
# 37          37  @_Ozick Там ролевики какие-то и они с помощью ...   neutral
# 38          38                               @miirozzdaniie Ебошь  negative
# 39          39    когда очень хочется сменить форму и тебе скучно  negative
# 40          40  три руки вышли из дохуллион, можно отпраздновать.  negative
# 41          41  Ачё куда все пропали.. Я твит два часа назад с...   neutral
# 42          42         @avantroux @Plesk7 @mix87074735444 Услышал      skip
# 43          43  всем привет мем вышел из под контроля это боль...   neutral
# 44          44  @romanponomaryov @navalny @DrAnastasy @vigimad...  negative
# 45          45  иоооо нэг тариа тариулсан үхэхжийн 💉\nбаруун т...      skip
# 46          46  итак время софтить тэхена\n https://t.co/H8wwf...  positive
# 47          47             @dontwastemyouth мне так приятно❤️❤️🥺🥺  positive
# 48          48  @raccoonya2 О ма гад. У меня даже такого не бы...   neutral
# 49          49           @motherland_sale думаю тут грань размыта   neutral
#
#                        id                                         clean_text  \
# 0   1,32793476580731E+018                                 varlamov mcfaul на
# 1   1,25294318138735E+018  велла они всё равно что мусор так что ничего с...
# 2   1,32361066906168E+018  трезвый жизнь какаять такой стрёмный с артём a...
# 3   1,33623166116025E+018  ой какой неожиданный результат httpstcozwohpdkuqq
# 4   1,29242173645413E+018  shvonder_chief dimsmirnov на забор тоже написа...
# 5   1,30375391117461E+018          idkwhht мы тоже мебельный компания уджина
# 6    1,3399173764276E+018        счастие здоровье классник httpstcomvunsixdi
# 7   1,26789820717614E+018                                  dntbliev не пасть
# 8   1,28155155170687E+018                          bts_twt ты такой красивый
# 9   1,25776169012236E+018                             ladyzchensk цыган хула
# 10  1,27529845683649E+018     nikogdanahui с день рождение успех и победа ты
# 11  1,23627385967183E+018  okdaa wifeyoonminn y_yoon_ но ты очень красиво...
# 12  1,28817330914274E+018    luvyurbodybby я играть в волейбол не ради смысл
# 13  1,28992696860826E+018                                    susanoo вхвхвха
# 14  1,29902131858791E+018  tutby день выборы президент беларусь начать оп...
# 15  1,29077313172509E+018                          zippinkc lenny_lanzz плач
# 16  1,29190252773524E+018  bettyboo_rus надо тоже надоедать начать спасиб...
# 17   1,2621024634124E+018  shn_shah кечий топилмагунч уйқий кемаганди муш...
# 18  1,33893327108277E+018                 yoursungshine малышка спать сладко
# 19  1,28531835546604E+018  lil__muna__ kpop_asiangirl хех я просто объясн...
# 20  1,32810192559482E+018  blianaaaa я такожа творить хуйня тот давать тв...
# 21  1,33553743673947E+018  gygwas я уже готовый быть выебанный через экра...
# 22  1,28166686991789E+018  viktoshamurrr cmeptu___het derella кладбище до...
# 23  1,21892615122732E+018            как же я любить титька httpstcocmrmdfyc
# 24  1,25512299893331E+018                        nimitide_ne абаммёд мухдуло
# 25  1,30369014519192E+018      обсуждать последний новость httpstcobjxlbowog
# 26  1,29588042662043E+018                      ughdaechwitta всё мужик такой
# 27  1,31784768697711E+018  реакция болельщик челси на трансфер виктор моз...
# 28  1,27685872530801E+018                           это как то странно чтлио
# 29  1,24800899379812E+018  ощущать на себя выражение влачить свой существ...
# 30  1,27852034500012E+018  вы помнить когда зарегистрироваться в твиттер ...
# 31  1,34177013471795E+018  стэнить гат быть мой самый хороший решение на ...
# 32   1,3352445610908E+018                  simpforkeijii ахах ладный спасибо
# 33  1,21673774373849E+018  naiveximp вийти отсюда розбійник писать мой хо...
# 34  1,25147926442956E+018                 xiaogoldjoy littlebear_j согласный
# 35  1,34422269947277E+018          krimoza_k ateezofficial и целый два сразу
# 36  1,23924840136518E+018           poohrus а весь список огласить не судьба
# 37  1,29327984073766E+018  _ozick там ролевика какиеть и они с помощь наш...
# 38  1,24063422875012E+018                                miirozzdaniie ебошь
# 39  1,22904309348951E+018     когда очень хотеться сменить форма и ты скучно
# 40  1,26541340921604E+018    три рука выйти из дохуллион можно отпраздновать
# 41  1,32475087805055E+018  ачё куда всё пропасть я твит два час назад сде...
# 42   1,2670828554585E+018                       avantroux plesk mix услышать
# 43  1,26870694868739E+018  весь привет мем выйти из под контроль это боль...
# 44  1,24622416643439E+018  romanponomaryov navalny dranastasy vigimadi по...
# 45  1,28769729760676E+018  иоооо нэг тариа тариулсан үхэхжийна баруун тал...
# 46  1,26211954259733E+018          итак время софтить тэхен httpstcohwwficev
# 47  1,25086086467412E+018                      dontwastemyouth я так приятно
# 48   1,2969210124754E+018          raccoonya о ма гад у я даже такой не быть
# 49  1,31890534364105E+018           motherland_sale думать тут грань размыть
#
#                                       vectorized_text      tone
# 0     (0, 269)\t0.4195509891106602\n  (0, 60)\t0.6...   neutral
# 1     (0, 409)\t0.3301957582920934\n  (0, 282)\t0....  negative
# 2     (0, 7)\t0.3986021850260091\n  (0, 107)\t0.39...  negative
# 3     (0, 43)\t0.45940351095040555\n  (0, 359)\t0....  positive
# 4     (0, 143)\t0.2819257586136414\n  (0, 392)\t0....   neutral
# 5     (0, 452)\t0.42623255053817144\n  (0, 227)\t0...   neutral
# 6     (0, 32)\t0.5\n  (0, 224)\t0.5\n  (0, 198)\t0...    speech
# 7     (0, 313)\t0.6384933294190861\n  (0, 279)\t0....   neutral
# 8     (0, 236)\t0.5949625294958931\n  (0, 444)\t0....  positive
# 9     (0, 467)\t0.5773502691896257\n  (0, 470)\t0....      skip
# 10    (0, 325)\t0.4458486342992762\n  (0, 458)\t0....    speech
